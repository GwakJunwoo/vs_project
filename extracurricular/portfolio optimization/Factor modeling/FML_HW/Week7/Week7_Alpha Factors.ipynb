# %%
import FinanceDataReader as fdr

df_spx = fdr.StockListing('NASDAQ')
# Out:
# 100%|██████████| 4574/4574 [00:06<00:00, 742.57it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4e384f5cc014> in <module>()
#       1 import FinanceDataReader as fdr
#       2
# ----> 3 df_spx = fdr.StockListing('NASDAQ')
#
# C:\Users\lunar\anaconda3\envs\p36env\lib\site-packages\FinanceDataReader\data.py in StockListing(market)
#      58     market = market.upper()
#      59     if market in [ 'NASDAQ', 'NYSE', 'AMEX', 'SSE', 'SZSE', 'HKEX', 'TSE', 'HOSE']:
# ---> 60         return NaverStockListing(market).read()
#      61     if market in [ 'KRX', 'KOSPI', 'KOSDAQ', 'KONEX']:
#      62         return KrxStockListing(market).read()
#
# C:\Users\lunar\anaconda3\envs\p36env\lib\site-packages\FinanceDataReader\naver\listing.py in read(self)
#      90                     'industryCodeType.industryGroupKor':'Industry',
# ...

# %%
df_spx
# Out:
#     Symbol                          Name                  Sector  \
# 0      MMM                            3M             Industrials
# 1      AOS                   A. O. Smith             Industrials
# 2      ABT                        Abbott             Health Care
# 3     ABBV                        AbbVie             Health Care
# 4     ABMD                       Abiomed             Health Care
# 5      ACN                     Accenture  Information Technology
# 6     ATVI           Activision Blizzard  Communication Services
# 7      ADM                           ADM        Consumer Staples
# 8     ADBE                         Adobe  Information Technology
# 9      ADP                           ADP  Information Technology
# 10     AAP            Advance Auto Parts  Consumer Discretionary
# 11     AES                           AES               Utilities
# 12     AFL                         Aflac              Financials
# ...
