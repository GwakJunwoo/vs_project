# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('KRX_주요주가지수.csv',encoding='euc-kr')
idx = df['지수종류별(1)']
index_df = df.iloc[:,-30:]; index_df.index = idx

df = pd.read_excel('stat_107301.xls')
idx = df['통계표명:'][2:]
interest_df = df.iloc[2:, :].drop([]); interest_df.index = idx

# %%
interest_df
# Out:
#                    통계표명:                                            시장금리 추이  \
# 통계표명:
# 국고채 3년(평균)    국고채 3년(평균)                                               1.25
# 국고채 5년(평균)    국고채 5년(평균)                                               1.36
# 국고채 10년(평균)  국고채 10년(평균)                                               1.54
# 회사채 3년(평균)    회사채 3년(평균)                                               1.85
# CD 91물(평균)    CD 91물(평균)                                               1.42
# 콜금리(1일물,평균)  콜금리(1일물,평균)                                               1.24
# 기준금리                기준금리                                               1.25
# 출처:                  출처:                            한국은행 경제통계시스템 &gt; 4. 금리
# 주석:                  주석:  * 콜금리 목표는 월말 기준이며,국고채10년은 00.11월부터, 콜금리목표는 99....
#
#             Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 통계표명:
# 국고채 3년(평균)        1.09       1.02       0.88       0.85       0.83       0.83
# ...
